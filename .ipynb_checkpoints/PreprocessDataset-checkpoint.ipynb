# %% [markdown]
# ## Preparing Loinc data for listwise search approach

# %%
#Imports
try: 
    import pandas as pd 
    import nltk, os, re, math, spacy
    import numpy as np
    from spacy.cli import download
    from sklearn.model_selection import train_test_split
except: 
    print("Install the requirements.txt")

# Requirements: Active and running version of spacy on the computer
# !Uncomment the following part only if model isn't loaded. The download can take several minutes!
"""
download('en_core_web_lg')

nlp = spacy.load('en_core_web_lg')
"""
# Out:
# "\ndownload('en_core_web_lg')\n\nnlp = spacy.load('en_core_web_lg')\n"

# %% [markdown]
# ### Read Data from .xlsx (excel) format
#
# Since the loinc datasets are stored in excel format it is necessary to load them into dataframes for further processing tasks. We have decided to keep the given layout in order to provide future possible compatibility.

# %%
#This functions enables the automated reading of xlsx files and the corrosponding data sheets
#Output is a merged dataframe aswell as the queries in each datasheets and the relevancelevels of the data. 
def read_data_sheets(dataset, sheet_names):
    queries = []
    cols = ['loinc_num', 'long_common_name', 'component', 'system', 'property','qid', 'label']
    df = pd.DataFrame(columns = cols)
    for name in sheet_names:
        query = pd.read_excel(f"./{dataset}",nrows = 1, sheet_name=name)
        query = query.columns[0].split(" ")
        current_df = pd.read_excel(f"./{dataset}",skiprows=2, sheet_name=name)
        current_df["query"] = pd.Series([query[1:len(query)] for x in range(len(current_df.index))])
        queries.append(query)
        df = pd.concat([df, current_df],ignore_index=True, axis=0)
    return df, queries

#Function to transform Array of Format Q1 ["This", "is","an", "example"] into a str
def query_to_str(query) -> str: 
    q  = str()
    for i,word in enumerate(query[1:len(query)]):
        if(i < len(query)):
            q = q + word+" "
        else:
            q = q + word
    query = q
    return query

# %%
#Specify the datasheets that are relevant 
#Possible:  ["glucose in blood","bilirubin in plasma","white blood cells count"]
ds_names = ["white blood cells count"]

df, queries = read_data_sheets('loinc_dataset_extended.xlsx',ds_names)
print(df.shape)
# Out:
# (200, 15)

# %% [markdown]
# ### Building Parameters for Listwise Approach
#
# In order to build parameters we took a close look at an already well established ranking benchmark set.
# <br/>
# Url: https://arxiv.org/ftp/arxiv/papers/1306/1306.2597.pdf (also included in the our resources)
#
# <br/>
# While the Letor 4 Ranking dataset has more than 40 parameters we reduced the amounts of parameters significantly. Main goal of this code is to show a proof of concept of the listwise approach.
#
# #### Calculating term frequencies

# %%
#Constructing Parameter => TF Score
#The TF Score counts the overall occourcences of a word in the query in regard to the occurences per row

# https://t4tutorials.com/cosine-similarity-in-data-mining/
def termFrequency(term, document) -> float:
  return document.count(term.lower()) / float(len(document))
    

#Idea: We compute the tf for each Loinc Entry in regard to the query. 
#Since we use an addition, there is the possibility of value exceeding 1. Therefore the data will be scaled afterwards.
# This might be not the mathematiclly cleaneast approach but we assume that an overall high overlap in words in the query with
# words in the row description of an loinc entry is an indicator for significance. 
def add_termFrequencies(col,name) -> pd.DataFrame:
    tf_arr = []
    for idx,txt in enumerate(df[col]): 
        qd_tf = 0
        for idx, trm in enumerate(df["query"][idx]): 
            #print(txt)
            qd_tf = qd_tf + termFrequency(trm.lower(),txt.lower())
        tf_arr.append(qd_tf)
    return pd.DataFrame(tf_arr, columns=[name])

#After the calculation of the tf scores we append them to the df as new column. 
df["lcmon_tf"] =  add_termFrequencies("long_common_name","lcmon_tf")
df["cmp_tf"] = add_termFrequencies("component","cmp_tf")

print(df["lcmon_tf"].shape, df["cmp_tf"].shape)
# Out:
# Bilirubin.total [Presence] in Unspecified specimen
# Bilirubin.total [Presence] in Unspecified specimen
# Bilirubin.total [Presence] in Unspecified specimen
# Bilirubin.total [Presence] in Unspecified specimen
# Calcium [Moles/volume] corrected for albumin in Serum or Plasma
# Calcium [Moles/volume] corrected for albumin in Serum or Plasma
# Calcium [Moles/volume] corrected for albumin in Serum or Plasma
# Calcium [Moles/volume] corrected for albumin in Serum or Plasma
# Bilirubin.total [Mass/volume] in Synovial fluid
# Bilirubin.total [Mass/volume] in Synovial fluid
# Bilirubin.total [Mass/volume] in Synovial fluid
# Bilirubin.total [Mass/volume] in Synovial fluid
# Other Antibiotic [Susceptibility]
# Other Antibiotic [Susceptibility]
# Other Antibiotic [Susceptibility]
# Other Antibiotic [Susceptibility]
# Vancomycin [Susceptibility]
# Vancomycin [Susceptibility]
# Vancomycin [Susceptibility]
# Vancomycin [Susceptibility]
# Glucose [Moles/volume] in Serum or Plasma
# Glucose [Moles/volume] in Serum or Plasma
# Glucose [Moles/volume] in Serum or Plasma
# Glucose [Moles/volume] in Serum or Plasma
# Aspartate aminotransferase [Enzymatic activity/volume] in Serum or Plasma
# Aspartate aminotransferase [Enzymatic activity/volume] in Serum or Plasma
# Aspartate aminotransferase [Enzymatic activity/volume] in Serum or Plasma
# Aspartate aminotransferase [Enzymatic activity/volume] in Serum or Plasma
# Cefazolin [Susceptibility]
# Cefazolin [Susceptibility]
# Cefazolin [Susceptibility]
# Cefazolin [Susceptibility]
# Hepatitis B virus DNA [#/volume] (viral load) in Serum by Probe with signal amplification
# Hepatitis B virus DNA [#/volume] (viral load) in Serum by Probe with signal amplification
# Hepatitis B virus DNA [#/volume] (viral load) in Serum by Probe with signal amplification
# Hepatitis B virus DNA [#/volume] (viral load) in Serum by Probe with signal amplification
# Albumin [Mass/volume] in Serum or Plasma
# Albumin [Mass/volume] in Serum or Plasma
# Albumin [Mass/volume] in Serum or Plasma
# Albumin [Mass/volume] in Serum or Plasma
# Methicillin resistant Staphylococcus aureus [Presence] in Unspecified specimen by Organism specific culture
# Methicillin resistant Staphylococcus aureus [Presence] in Unspecified specimen by Organism specific culture
# Methicillin resistant Staphylococcus aureus [Presence] in Unspecified specimen by Organism specific culture
# Methicillin resistant Staphylococcus aureus [Presence] in Unspecified specimen by Organism specific culture
# Glucose [Moles/volume] in Urine
# Glucose [Moles/volume] in Urine
# Glucose [Moles/volume] in Urine
# Glucose [Moles/volume] in Urine
# Fasting glucose [Mass or Moles/volume] in Serum or Plasma
# Fasting glucose [Mass or Moles/volume] in Serum or Plasma
# Fasting glucose [Mass or Moles/volume] in Serum or Plasma
# Fasting glucose [Mass or Moles/volume] in Serum or Plasma
# Cholesterol in HDL [Mass/volume] in Serum or Plasma
# Cholesterol in HDL [Mass/volume] in Serum or Plasma
# Cholesterol in HDL [Mass/volume] in Serum or Plasma
# Cholesterol in HDL [Mass/volume] in Serum or Plasma
# Leukocytes [#/volume] in Blood
# Leukocytes [#/volume] in Blood
# Leukocytes [#/volume] in Blood
# Leukocytes [#/volume] in Blood
# Blood product disposition [Type]
# Blood product disposition [Type]
# Blood product disposition [Type]
# Blood product disposition [Type]
# Calcium.ionized [Moles/volume] in Blood
# Calcium.ionized [Moles/volume] in Blood
# Calcium.ionized [Moles/volume] in Blood
# Calcium.ionized [Moles/volume] in Blood
# Amylase [Enzymatic activity/volume] in Serum or Plasma
# Amylase [Enzymatic activity/volume] in Serum or Plasma
# Amylase [Enzymatic activity/volume] in Serum or Plasma
# Amylase [Enzymatic activity/volume] in Serum or Plasma
# Bicarbonate [Moles/volume] in Blood
# Bicarbonate [Moles/volume] in Blood
# Bicarbonate [Moles/volume] in Blood
# Bicarbonate [Moles/volume] in Blood
# Bilirubin.total [Mass/volume] in Serum or Plasma
# Bilirubin.total [Mass/volume] in Serum or Plasma
# Bilirubin.total [Mass/volume] in Serum or Plasma
# Bilirubin.total [Mass/volume] in Serum or Plasma
# Gentamicin [Susceptibility]
# Gentamicin [Susceptibility]
# Gentamicin [Susceptibility]
# Gentamicin [Susceptibility]
# ABO group [Type] in Blood from Blood product unit
# ABO group [Type] in Blood from Blood product unit
# ABO group [Type] in Blood from Blood product unit
# ABO group [Type] in Blood from Blood product unit
# Blood product unit ID [#]
# Blood product unit ID [#]
# Blood product unit ID [#]
# Blood product unit ID [#]
# Protein C [Mass/volume] in Plasma
# Protein C [Mass/volume] in Plasma
# Protein C [Mass/volume] in Plasma
# Protein C [Mass/volume] in Plasma
# Chloride [Moles/volume] in Blood
# Chloride [Moles/volume] in Blood
# Chloride [Moles/volume] in Blood
# Chloride [Moles/volume] in Blood
# Choriogonadotropin.beta subunit [Moles/volume] in Serum or Plasma
# Choriogonadotropin.beta subunit [Moles/volume] in Serum or Plasma
# Choriogonadotropin.beta subunit [Moles/volume] in Serum or Plasma
# Choriogonadotropin.beta subunit [Moles/volume] in Serum or Plasma
# Calcium [Mass/volume] in Serum or Plasma
# Calcium [Mass/volume] in Serum or Plasma
# Calcium [Mass/volume] in Serum or Plasma
# Calcium [Mass/volume] in Serum or Plasma
# Chloride [Moles/volume] in Serum or Plasma
# Chloride [Moles/volume] in Serum or Plasma
# Chloride [Moles/volume] in Serum or Plasma
# Chloride [Moles/volume] in Serum or Plasma
# Blood product type
# Blood product type
# Blood product type
# Blood product type
# Cobalamin (Vitamin B12) [Mass/volume] in Serum
# Cobalamin (Vitamin B12) [Mass/volume] in Serum
# Cobalamin (Vitamin B12) [Mass/volume] in Serum
# Cobalamin (Vitamin B12) [Mass/volume] in Serum
# Choriogonadotropin [Units/volume] in Serum or Plasma
# Choriogonadotropin [Units/volume] in Serum or Plasma
# Choriogonadotropin [Units/volume] in Serum or Plasma
# Choriogonadotropin [Units/volume] in Serum or Plasma
# Lymphocytes/100 leukocytes in Blood
# Lymphocytes/100 leukocytes in Blood
# Lymphocytes/100 leukocytes in Blood
# Lymphocytes/100 leukocytes in Blood
# Glucose [Moles/volume] in Pleural fluid
# Glucose [Moles/volume] in Pleural fluid
# Glucose [Moles/volume] in Pleural fluid
# Glucose [Moles/volume] in Pleural fluid
# Carbon dioxide, total [Moles/volume] in Blood
# Carbon dioxide, total [Moles/volume] in Blood
# Carbon dioxide, total [Moles/volume] in Blood
# Carbon dioxide, total [Moles/volume] in Blood
# Carbon dioxide, total [Moles/volume] in Serum or Plasma
# Carbon dioxide, total [Moles/volume] in Serum or Plasma
# Carbon dioxide, total [Moles/volume] in Serum or Plasma
# Carbon dioxide, total [Moles/volume] in Serum or Plasma
# Nitrofurantoin [Susceptibility]
# Nitrofurantoin [Susceptibility]
# Nitrofurantoin [Susceptibility]
# Nitrofurantoin [Susceptibility]
# Cholesterol [Mass/volume] in Serum or Plasma
# Cholesterol [Mass/volume] in Serum or Plasma
# Cholesterol [Mass/volume] in Serum or Plasma
# Cholesterol [Mass/volume] in Serum or Plasma
# Trimethoprim+Sulfamethoxazole [Susceptibility]
# Trimethoprim+Sulfamethoxazole [Susceptibility]
# Trimethoprim+Sulfamethoxazole [Susceptibility]
# Trimethoprim+Sulfamethoxazole [Susceptibility]
# Blood group antibody screen [Presence] in Serum or Plasma
# Blood group antibody screen [Presence] in Serum or Plasma
# Blood group antibody screen [Presence] in Serum or Plasma
# Blood group antibody screen [Presence] in Serum or Plasma
# Glucose [Moles/volume] in Serum or Plasma --3 hours post 100 g glucose PO
# Glucose [Moles/volume] in Serum or Plasma --3 hours post 100 g glucose PO
# Glucose [Moles/volume] in Serum or Plasma --3 hours post 100 g glucose PO
# Glucose [Moles/volume] in Serum or Plasma --3 hours post 100 g glucose PO
# Cortisol [Mass/volume] in Serum or Plasma
# Cortisol [Mass/volume] in Serum or Plasma
# Cortisol [Mass/volume] in Serum or Plasma
# Cortisol [Mass/volume] in Serum or Plasma
# Carcinoembryonic Ag [Mass/volume] in Serum or Plasma
# Carcinoembryonic Ag [Mass/volume] in Serum or Plasma
# Carcinoembryonic Ag [Mass/volume] in Serum or Plasma
# Carcinoembryonic Ag [Mass/volume] in Serum or Plasma
# Bilirubin.indirect [Mass/volume] in Serum or Plasma
# Bilirubin.indirect [Mass/volume] in Serum or Plasma
# Bilirubin.indirect [Mass/volume] in Serum or Plasma
# Bilirubin.indirect [Mass/volume] in Serum or Plasma
# Ciprofloxacin [Susceptibility]
# Ciprofloxacin [Susceptibility]
# Ciprofloxacin [Susceptibility]
# Ciprofloxacin [Susceptibility]
# Alkaline phosphatase [Enzymatic activity/volume] in Serum or Plasma
# Alkaline phosphatase [Enzymatic activity/volume] in Serum or Plasma
# Alkaline phosphatase [Enzymatic activity/volume] in Serum or Plasma
# Alkaline phosphatase [Enzymatic activity/volume] in Serum or Plasma
# C reactive protein [Mass/volume] in Serum or Plasma
# C reactive protein [Mass/volume] in Serum or Plasma
# C reactive protein [Mass/volume] in Serum or Plasma
# C reactive protein [Mass/volume] in Serum or Plasma
# Glucose [Mass/volume] in Serum, Plasma or Blood
# Glucose [Mass/volume] in Serum, Plasma or Blood
# Glucose [Mass/volume] in Serum, Plasma or Blood
# Glucose [Mass/volume] in Serum, Plasma or Blood
# Calcium.ionized [Moles/volume] in Serum or Plasma
# Calcium.ionized [Moles/volume] in Serum or Plasma
# Calcium.ionized [Moles/volume] in Serum or Plasma
# Calcium.ionized [Moles/volume] in Serum or Plasma
# Albumin/Globulin [Mass ratio] in Serum or Plasma
# Albumin/Globulin [Mass ratio] in Serum or Plasma
# Albumin/Globulin [Mass ratio] in Serum or Plasma
# Albumin/Globulin [Mass ratio] in Serum or Plasma
# Levofloxacin [Susceptibility]
# Levofloxacin [Susceptibility]
# Levofloxacin [Susceptibility]
# Levofloxacin [Susceptibility]
# Bilirubin.direct [Mass/volume] in Serum or Plasma
# Bilirubin.direct [Mass/volume] in Serum or Plasma
# Bilirubin.direct [Mass/volume] in Serum or Plasma
# Bilirubin.direct [Mass/volume] in Serum or Plasma
# Bilirubin.indirect [Mass or Moles/volume] in Serum or Plasma
# Bilirubin.indirect [Mass or Moles/volume] in Serum or Plasma
# Bilirubin.indirect [Mass or Moles/volume] in Serum or Plasma
# Bilirubin.indirect [Mass or Moles/volume] in Serum or Plasma
# ABO group [Type] in Blood
# ABO group [Type] in Blood
# ABO group [Type] in Blood
# ABO group [Type] in Blood
# Indirect antiglobulin test.complement specific reagent [Presence] in Serum or Plasma
# Indirect antiglobulin test.complement specific reagent [Presence] in Serum or Plasma
# Indirect antiglobulin test.complement specific reagent [Presence] in Serum or Plasma
# Indirect antiglobulin test.complement specific reagent [Presence] in Serum or Plasma
# Calcium bilirubinate/Total in Stone
# Calcium bilirubinate/Total in Stone
# Calcium bilirubinate/Total in Stone
# Calcium bilirubinate/Total in Stone
# Tyrosine aminotransferase [Mass/volume] in Plasma
# Tyrosine aminotransferase [Mass/volume] in Plasma
# Tyrosine aminotransferase [Mass/volume] in Plasma
# Tyrosine aminotransferase [Mass/volume] in Plasma
# C reactive protein [Mass/volume] in Serum or Plasma by High sensitivity method
# C reactive protein [Mass/volume] in Serum or Plasma by High sensitivity method
# C reactive protein [Mass/volume] in Serum or Plasma by High sensitivity method
# C reactive protein [Mass/volume] in Serum or Plasma by High sensitivity method
# Rh [Type] in Blood
# Rh [Type] in Blood
# Rh [Type] in Blood
# Rh [Type] in Blood
# Lymphocytes [#/volume] in Blood
# Lymphocytes [#/volume] in Blood
# Lymphocytes [#/volume] in Blood
# Lymphocytes [#/volume] in Blood
# Body temperature
# Body temperature
# Body temperature
# Body temperature
# Hematocrit [Volume Fraction] of Blood by Impedance
# Hematocrit [Volume Fraction] of Blood by Impedance
# Hematocrit [Volume Fraction] of Blood by Impedance
# Hematocrit [Volume Fraction] of Blood by Impedance
# ABO & Rh group [Type] in Blood
# ABO & Rh group [Type] in Blood
# ABO & Rh group [Type] in Blood
# ABO & Rh group [Type] in Blood
# Monocytes [#/volume] in Blood
# Monocytes [#/volume] in Blood
# Monocytes [#/volume] in Blood
# Monocytes [#/volume] in Blood
# Major crossmatch [interpretation]
# Major crossmatch [interpretation]
# Major crossmatch [interpretation]
# Major crossmatch [interpretation]
# Ampicillin [Susceptibility]
# Ampicillin [Susceptibility]
# Ampicillin [Susceptibility]
# Ampicillin [Susceptibility]
# Alanine aminotransferase [Enzymatic activity/volume] in Serum or Plasma
# Alanine aminotransferase [Enzymatic activity/volume] in Serum or Plasma
# Alanine aminotransferase [Enzymatic activity/volume] in Serum or Plasma
# Alanine aminotransferase [Enzymatic activity/volume] in Serum or Plasma
# Ampicillin+Sulbactam [Susceptibility]
# Ampicillin+Sulbactam [Susceptibility]
# Ampicillin+Sulbactam [Susceptibility]
# Ampicillin+Sulbactam [Susceptibility]
# "Smudge cells/Leukocytes [Pure number fraction] in Blood by Manual count"
# "Smudge cells/Leukocytes [Pure number fraction] in Blood by Manual count"
# "Smudge cells/Leukocytes [Pure number fraction] in Blood by Manual count"
# "Smudge cells/Leukocytes [Pure number fraction] in Blood by Manual count"
# "Mononuclear cells/100 leukocytes in Blood by Manual count"
# "Mononuclear cells/100 leukocytes in Blood by Manual count"
# "Mononuclear cells/100 leukocytes in Blood by Manual count"
# "Mononuclear cells/100 leukocytes in Blood by Manual count"
# "Plasma cells/100 leukocytes in Blood by Manual count"
# "Plasma cells/100 leukocytes in Blood by Manual count"
# "Plasma cells/100 leukocytes in Blood by Manual count"
# "Plasma cells/100 leukocytes in Blood by Manual count"
# "Sezary cells/100 leukocytes in Blood by Manual count"
# "Sezary cells/100 leukocytes in Blood by Manual count"
# "Sezary cells/100 leukocytes in Blood by Manual count"
# "Sezary cells/100 leukocytes in Blood by Manual count"
# "Smudge cells/100 leukocytes in Blood by Manual count"
# "Smudge cells/100 leukocytes in Blood by Manual count"
# "Smudge cells/100 leukocytes in Blood by Manual count"
# "Smudge cells/100 leukocytes in Blood by Manual count"
# "Unidentified cells/100 leukocytes in Blood by Manual count"
# "Unidentified cells/100 leukocytes in Blood by Manual count"
# "Unidentified cells/100 leukocytes in Blood by Manual count"
# "Unidentified cells/100 leukocytes in Blood by Manual count"
# "Hairy cells/100 leukocytes in Blood by Manual count"
# "Hairy cells/100 leukocytes in Blood by Manual count"
# "Hairy cells/100 leukocytes in Blood by Manual count"
# "Hairy cells/100 leukocytes in Blood by Manual count"
# "Lymphoma cells/100 leukocytes in Blood by Manual count"
# "Lymphoma cells/100 leukocytes in Blood by Manual count"
# "Lymphoma cells/100 leukocytes in Blood by Manual count"
# "Lymphoma cells/100 leukocytes in Blood by Manual count"
# "Malignant cells/100 leukocytes in Blood by Manual count"
# "Malignant cells/100 leukocytes in Blood by Manual count"
# "Malignant cells/100 leukocytes in Blood by Manual count"
# "Malignant cells/100 leukocytes in Blood by Manual count"
# "Other cells/100 leukocytes in Blood by Automated count"
# "Other cells/100 leukocytes in Blood by Automated count"
# "Other cells/100 leukocytes in Blood by Automated count"
# "Other cells/100 leukocytes in Blood by Automated count"
# "Other cells/100 leukocytes in Blood by Manual count"
# "Other cells/100 leukocytes in Blood by Manual count"
# "Other cells/100 leukocytes in Blood by Manual count"
# "Other cells/100 leukocytes in Blood by Manual count"
# "Mononuclear cells immature/100 leukocytes in Blood by Manual count"
# "Mononuclear cells immature/100 leukocytes in Blood by Manual count"
# "Mononuclear cells immature/100 leukocytes in Blood by Manual count"
# "Mononuclear cells immature/100 leukocytes in Blood by Manual count"
# "Mononuclear cells atypical/100 leukocytes in Blood by Manual count"
# "Mononuclear cells atypical/100 leukocytes in Blood by Manual count"
# "Mononuclear cells atypical/100 leukocytes in Blood by Manual count"
# "Mononuclear cells atypical/100 leukocytes in Blood by Manual count"
# "Unidentified cells/100 leukocytes in Blood by Automated count"
# "Unidentified cells/100 leukocytes in Blood by Automated count"
# "Unidentified cells/100 leukocytes in Blood by Automated count"
# "Unidentified cells/100 leukocytes in Blood by Automated count"
# "Mononuclear cells/100 leukocytes in Urine sediment by Manual count"
# "Mononuclear cells/100 leukocytes in Urine sediment by Manual count"
# "Mononuclear cells/100 leukocytes in Urine sediment by Manual count"
# "Mononuclear cells/100 leukocytes in Urine sediment by Manual count"
# "Mesothelial cells/100 leukocytes in Blood by Manual count"
# "Mesothelial cells/100 leukocytes in Blood by Manual count"
# "Mesothelial cells/100 leukocytes in Blood by Manual count"
# "Mesothelial cells/100 leukocytes in Blood by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Blood by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Blood by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Blood by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Blood by Manual count"
# "Other cells/100 leukocytes in Bronchial specimen by Manual count"
# "Other cells/100 leukocytes in Bronchial specimen by Manual count"
# "Other cells/100 leukocytes in Bronchial specimen by Manual count"
# "Other cells/100 leukocytes in Bronchial specimen by Manual count"
# "Other cells/100 leukocytes in Dialysis fluid by Manual count"
# "Other cells/100 leukocytes in Dialysis fluid by Manual count"
# "Other cells/100 leukocytes in Dialysis fluid by Manual count"
# "Other cells/100 leukocytes in Dialysis fluid by Manual count"
# "Other cells/100 leukocytes in Pleural fluid by Manual count"
# "Other cells/100 leukocytes in Pleural fluid by Manual count"
# "Other cells/100 leukocytes in Pleural fluid by Manual count"
# "Other cells/100 leukocytes in Pleural fluid by Manual count"
# "Other cells/100 leukocytes in Sputum by Manual count"
# "Other cells/100 leukocytes in Sputum by Manual count"
# "Other cells/100 leukocytes in Sputum by Manual count"
# "Other cells/100 leukocytes in Sputum by Manual count"
# "Plasma cells.centroblasts/100 leukocytes in Blood by Manual count"
# "Plasma cells.centroblasts/100 leukocytes in Blood by Manual count"
# "Plasma cells.centroblasts/100 leukocytes in Blood by Manual count"
# "Plasma cells.centroblasts/100 leukocytes in Blood by Manual count"
# "Plasma cells.centrocytes/100 leukocytes in Blood by Manual count"
# "Plasma cells.centrocytes/100 leukocytes in Blood by Manual count"
# "Plasma cells.centrocytes/100 leukocytes in Blood by Manual count"
# "Plasma cells.centrocytes/100 leukocytes in Blood by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Peritoneal fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Peritoneal fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Peritoneal fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Peritoneal fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Pleural fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Pleural fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Pleural fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Pleural fluid by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Urine by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Urine by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Urine by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Urine by Manual count"
# "Mononuclear cells/100 leukocytes in Stem cell product by Manual count"
# "Mononuclear cells/100 leukocytes in Stem cell product by Manual count"
# "Mononuclear cells/100 leukocytes in Stem cell product by Manual count"
# "Mononuclear cells/100 leukocytes in Stem cell product by Manual count"
# "Mononuclear cells/100 leukocytes in Peritoneal fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Peritoneal fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Peritoneal fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Peritoneal fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Semen by Manual count"
# "Mononuclear cells/100 leukocytes in Semen by Manual count"
# "Mononuclear cells/100 leukocytes in Semen by Manual count"
# "Mononuclear cells/100 leukocytes in Semen by Manual count"
# "Mononuclear cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Gastric fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Gastric fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Gastric fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Gastric fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Pericardial fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Pericardial fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Pericardial fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Pericardial fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Pleural fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Pleural fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Pleural fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Pleural fluid by Automated count"
# "Mononuclear cells/100 leukocytes in Pleural fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Pleural fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Pleural fluid by Manual count"
# "Mononuclear cells/100 leukocytes in Pleural fluid by Manual count"
# "Nonhematic cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Nonhematic cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Nonhematic cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Nonhematic cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Plasma cells/100 leukocytes in Pericardial fluid by Manual count"
# "Plasma cells/100 leukocytes in Pericardial fluid by Manual count"
# "Plasma cells/100 leukocytes in Pericardial fluid by Manual count"
# "Plasma cells/100 leukocytes in Pericardial fluid by Manual count"
# "Plasma cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Plasma cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Plasma cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Plasma cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Plasma cells/100 leukocytes in Pleural fluid by Manual count"
# "Plasma cells/100 leukocytes in Pleural fluid by Manual count"
# "Plasma cells/100 leukocytes in Pleural fluid by Manual count"
# "Plasma cells/100 leukocytes in Pleural fluid by Manual count"
# "Unidentified cells/100 leukocytes in Pericardial fluid by Manual count"
# "Unidentified cells/100 leukocytes in Pericardial fluid by Manual count"
# "Unidentified cells/100 leukocytes in Pericardial fluid by Manual count"
# "Unidentified cells/100 leukocytes in Pericardial fluid by Manual count"
# "Unspecified cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Unspecified cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Unspecified cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Unspecified cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Large unstained cells/100 leukocytes in Blood by Automated count"
# "Large unstained cells/100 leukocytes in Blood by Automated count"
# "Large unstained cells/100 leukocytes in Blood by Automated count"
# "Large unstained cells/100 leukocytes in Blood by Automated count"
# "Large unstained cells/100 leukocytes in Cord blood by Automated count"
# "Large unstained cells/100 leukocytes in Cord blood by Automated count"
# "Large unstained cells/100 leukocytes in Cord blood by Automated count"
# "Large unstained cells/100 leukocytes in Cord blood by Automated count"
# "Monocytoid cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Monocytoid cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Monocytoid cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Monocytoid cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Neoplastic cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Neoplastic cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Neoplastic cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Neoplastic cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Other cells/100 leukocytes in Stem cell product by Manual count"
# "Other cells/100 leukocytes in Stem cell product by Manual count"
# "Other cells/100 leukocytes in Stem cell product by Manual count"
# "Other cells/100 leukocytes in Stem cell product by Manual count"
# "Other cells/100 leukocytes in Body fluid by Manual count"
# "Other cells/100 leukocytes in Body fluid by Manual count"
# "Other cells/100 leukocytes in Body fluid by Manual count"
# "Other cells/100 leukocytes in Body fluid by Manual count"
# "Other cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Other cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Other cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Other cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Other cells/100 leukocytes in Pericardial fluid by Manual count"
# "Other cells/100 leukocytes in Pericardial fluid by Manual count"
# "Other cells/100 leukocytes in Pericardial fluid by Manual count"
# "Other cells/100 leukocytes in Pericardial fluid by Manual count"
# "Other cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Other cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Other cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Other cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Unspecified cells/100 leukocytes in Body fluid by Manual count"
# "Unspecified cells/100 leukocytes in Body fluid by Manual count"
# "Unspecified cells/100 leukocytes in Body fluid by Manual count"
# "Unspecified cells/100 leukocytes in Body fluid by Manual count"
# "Mononuclear cells atypical/100 leukocytes in Body fluid by Manual count"
# "Mononuclear cells atypical/100 leukocytes in Body fluid by Manual count"
# "Mononuclear cells atypical/100 leukocytes in Body fluid by Manual count"
# "Mononuclear cells atypical/100 leukocytes in Body fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Synovial fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Synovial fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Synovial fluid by Manual count"
# "Mononuclear cells/Leukocytes [Pure number fraction] in Synovial fluid by Manual count"
# "Plasma cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Plasma cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Plasma cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Plasma cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Plasma cells/Leukocytes [Pure number fraction] in Cerebral spinal fluid by Manual count"
# "Plasma cells/Leukocytes [Pure number fraction] in Cerebral spinal fluid by Manual count"
# "Plasma cells/Leukocytes [Pure number fraction] in Cerebral spinal fluid by Manual count"
# "Plasma cells/Leukocytes [Pure number fraction] in Cerebral spinal fluid by Manual count"
# "Unidentified cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Unidentified cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Unidentified cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Unidentified cells/Leukocytes [Pure number fraction] in Body fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Cerebral spinal fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Dialysis fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Dialysis fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Dialysis fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Dialysis fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Pericardial fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Pericardial fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Pericardial fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Pericardial fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Peritoneal fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Pleural fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Pleural fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Pleural fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Pleural fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Vitreous fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Vitreous fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Vitreous fluid by Manual count"
# "Mesothelial cells/100 leukocytes in Vitreous fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Pericardial fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Pericardial fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Pericardial fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Pericardial fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Peritoneal fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Peritoneal fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Peritoneal fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Peritoneal fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Pleural fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Pleural fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Pleural fluid by Manual count"
# "Mesothelial cells/Leukocytes [Pure number fraction] in Pleural fluid by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Gastric fluid by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Gastric fluid by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Gastric fluid by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Gastric fluid by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Pericardial fluid by Automated count"
# "Polymorphonuclear cells/100 leukocytes in Pericardial fluid by Automated count"
# "Polymorphonuclear cells/100 leukocytes in Pericardial fluid by Automated count"
# "Polymorphonuclear cells/100 leukocytes in Pericardial fluid by Automated count"
# "Polymorphonuclear cells/100 leukocytes in Pericardial fluid by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Pericardial fluid by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Pericardial fluid by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Pericardial fluid by Manual count"
# "Polymorphonuclear cells/100 leukocytes in Peritoneal fluid by Automated count"
# "Polymorphonuclear cells/100 leukocytes in Peritoneal fluid by Automated count"
# "Polymorphonuclear cells/100 leukocytes in Peritoneal fluid by Automated count"
# "Polymorphonuclear cells/100 leukocytes in Peritoneal fluid by Automated count"
# "Mesenteric artery Mean blood pressure"
# "Mesenteric artery Mean blood pressure"
# "Mesenteric artery Mean blood pressure"
# "Mesenteric artery Mean blood pressure"
# "Splenic artery Mean blood pressure"
# "Splenic artery Mean blood pressure"
# "Splenic artery Mean blood pressure"
# "Splenic artery Mean blood pressure"
# "Pressure max Respiratory system airway --during inspiration"
# "Pressure max Respiratory system airway --during inspiration"
# "Pressure max Respiratory system airway --during inspiration"
# "Pressure max Respiratory system airway --during inspiration"
# "Mean airway pressure --during inspiration"
# "Mean airway pressure --during inspiration"
# "Mean airway pressure --during inspiration"
# "Mean airway pressure --during inspiration"
# "Current number of unhealed pressure injuries at each stage - follow-up or discharge [CMS Assessment]"
# "Current number of unhealed pressure injuries at each stage - follow-up or discharge [CMS Assessment]"
# "Current number of unhealed pressure injuries at each stage - follow-up or discharge [CMS Assessment]"
# "Current number of unhealed pressure injuries at each stage - follow-up or discharge [CMS Assessment]"
# "Diameter.any.max Pressure injury.largest stage 3 or 4 [CMS Assessment]"
# "Diameter.any.max Pressure injury.largest stage 3 or 4 [CMS Assessment]"
# "Diameter.any.max Pressure injury.largest stage 3 or 4 [CMS Assessment]"
# "Diameter.any.max Pressure injury.largest stage 3 or 4 [CMS Assessment]"
# "Diastolic blood pressure 24 hour maximum"
# "Diastolic blood pressure 24 hour maximum"
# "Diastolic blood pressure 24 hour maximum"
# "Diastolic blood pressure 24 hour maximum"
# "Diastolic blood pressure 8 hour maximum"
# "Diastolic blood pressure 8 hour maximum"
# "Diastolic blood pressure 8 hour maximum"
# "Diastolic blood pressure 8 hour maximum"
# "Descending thoracic aorta Diastolic blood pressure"
# "Descending thoracic aorta Diastolic blood pressure"
# "Descending thoracic aorta Diastolic blood pressure"
# "Descending thoracic aorta Diastolic blood pressure"
# "Superior mesenteric artery Diastolic blood pressure"
# "Superior mesenteric artery Diastolic blood pressure"
# "Superior mesenteric artery Diastolic blood pressure"
# "Superior mesenteric artery Diastolic blood pressure"
# "Pulmonary artery End diastolic blood pressure"
# "Pulmonary artery End diastolic blood pressure"
# "Pulmonary artery End diastolic blood pressure"
# "Pulmonary artery End diastolic blood pressure"
# "Pulmonary artery wedge Mean blood pressure"
# "Pulmonary artery wedge Mean blood pressure"
# "Pulmonary artery wedge Mean blood pressure"
# "Pulmonary artery wedge Mean blood pressure"
# "Digital artery - left Systolic blood pressure"
# "Digital artery - left Systolic blood pressure"
# "Digital artery - left Systolic blood pressure"
# "Digital artery - left Systolic blood pressure"
# "Digital artery - right Systolic blood pressure"
# "Digital artery - right Systolic blood pressure"
# "Digital artery - right Systolic blood pressure"
# "Digital artery - right Systolic blood pressure"
# "Dorsal pedal artery Systolic blood pressure"
# "Dorsal pedal artery Systolic blood pressure"
# "Dorsal pedal artery Systolic blood pressure"
# "Dorsal pedal artery Systolic blood pressure"
# "Hepatic artery Systolic blood pressure"
# "Hepatic artery Systolic blood pressure"
# "Hepatic artery Systolic blood pressure"
# "Hepatic artery Systolic blood pressure"
# "Iliac artery - left Systolic blood pressure"
# "Iliac artery - left Systolic blood pressure"
# "Iliac artery - left Systolic blood pressure"
# "Iliac artery - left Systolic blood pressure"
# "Iliac artery - right Systolic blood pressure"
# "Iliac artery - right Systolic blood pressure"
# "Iliac artery - right Systolic blood pressure"
# "Iliac artery - right Systolic blood pressure"
# "Posterior tibial artery Systolic blood pressure"
# "Posterior tibial artery Systolic blood pressure"
# "Posterior tibial artery Systolic blood pressure"
# "Posterior tibial artery Systolic blood pressure"
# "Radial artery - left Systolic blood pressure"
# "Radial artery - left Systolic blood pressure"
# "Radial artery - left Systolic blood pressure"
# "Radial artery - left Systolic blood pressure"
# "Radial artery - right Systolic blood pressure"
# "Radial artery - right Systolic blood pressure"
# "Radial artery - right Systolic blood pressure"
# "Radial artery - right Systolic blood pressure"
# "Renal artery - left Systolic blood pressure"
# "Renal artery - left Systolic blood pressure"
# "Renal artery - left Systolic blood pressure"
# "Renal artery - left Systolic blood pressure"
# "Renal artery - right Systolic blood pressure"
# "Renal artery - right Systolic blood pressure"
# "Renal artery - right Systolic blood pressure"
# "Renal artery - right Systolic blood pressure"
# "Retinal artery - left Systolic blood pressure"
# "Retinal artery - left Systolic blood pressure"
# "Retinal artery - left Systolic blood pressure"
# "Retinal artery - left Systolic blood pressure"
# "Retinal artery - right Systolic blood pressure"
# "Retinal artery - right Systolic blood pressure"
# "Retinal artery - right Systolic blood pressure"
# "Retinal artery - right Systolic blood pressure"
# "Superior mesenteric artery Systolic blood pressure"
# "Superior mesenteric artery Systolic blood pressure"
# "Superior mesenteric artery Systolic blood pressure"
# "Superior mesenteric artery Systolic blood pressure"
# "Thumb arteries - left Systolic blood pressure"
# "Thumb arteries - left Systolic blood pressure"
# "Thumb arteries - left Systolic blood pressure"
# "Thumb arteries - left Systolic blood pressure"
# "Thumb arteries - right Systolic blood pressure"
# "Thumb arteries - right Systolic blood pressure"
# "Thumb arteries - right Systolic blood pressure"
# "Thumb arteries - right Systolic blood pressure"
# "Ulnar artery - left Systolic blood pressure"
# "Ulnar artery - left Systolic blood pressure"
# "Ulnar artery - left Systolic blood pressure"
# "Ulnar artery - left Systolic blood pressure"
# "Ulnar artery - right Systolic blood pressure"
# "Ulnar artery - right Systolic blood pressure"
# "Ulnar artery - right Systolic blood pressure"
# "Ulnar artery - right Systolic blood pressure"
# "Diastolic blood pressure 10 hour maximum"
# "Diastolic blood pressure 10 hour maximum"
# "Diastolic blood pressure 10 hour maximum"
# "Diastolic blood pressure 10 hour maximum"
# "Diastolic blood pressure 10 hour minimum"
# "Diastolic blood pressure 10 hour minimum"
# "Diastolic blood pressure 10 hour minimum"
# "Diastolic blood pressure 10 hour minimum"
# "Diastolic blood pressure 12 hour maximum"
# "Diastolic blood pressure 12 hour maximum"
# "Diastolic blood pressure 12 hour maximum"
# "Diastolic blood pressure 12 hour maximum"
# "Diastolic blood pressure 12 hour minimum"
# "Diastolic blood pressure 12 hour minimum"
# "Diastolic blood pressure 12 hour minimum"
# "Diastolic blood pressure 12 hour minimum"
# "Ascending thoracic aorta Diastolic blood pressure"
# "Ascending thoracic aorta Diastolic blood pressure"
# "Ascending thoracic aorta Diastolic blood pressure"
# "Ascending thoracic aorta Diastolic blood pressure"
# "Diastolic blood pressure by Continuous non-invasive monitoring"
# "Diastolic blood pressure by Continuous non-invasive monitoring"
# "Diastolic blood pressure by Continuous non-invasive monitoring"
# "Diastolic blood pressure by Continuous non-invasive monitoring"
# "Brachial artery Diastolic blood pressure"
# "Brachial artery Diastolic blood pressure"
# "Brachial artery Diastolic blood pressure"
# "Brachial artery Diastolic blood pressure"
# "Celiac trunk artery Diastolic blood pressure"
# "Celiac trunk artery Diastolic blood pressure"
# "Celiac trunk artery Diastolic blood pressure"
# "Celiac trunk artery Diastolic blood pressure"
# "Femoral artery Diastolic blood pressure"
# "Femoral artery Diastolic blood pressure"
# "Femoral artery Diastolic blood pressure"
# "Femoral artery Diastolic blood pressure"
# "Inferior mesenteric artery Diastolic blood pressure"
# "Inferior mesenteric artery Diastolic blood pressure"
# "Inferior mesenteric artery Diastolic blood pressure"
# "Inferior mesenteric artery Diastolic blood pressure"
# "Pulmonary capillary Diastolic blood pressure"
# "Pulmonary capillary Diastolic blood pressure"
# "Pulmonary capillary Diastolic blood pressure"
# "Pulmonary capillary Diastolic blood pressure"
# "Umbilical vein Diastolic blood pressure"
# "Umbilical vein Diastolic blood pressure"
# "Umbilical vein Diastolic blood pressure"
# "Umbilical vein Diastolic blood pressure"
# "Systolic blood pressure 24 hour maximum"
# "Systolic blood pressure 24 hour maximum"
# "Systolic blood pressure 24 hour maximum"
# "Systolic blood pressure 24 hour maximum"
# "Systolic blood pressure 24 hour minimum"
# "Systolic blood pressure 24 hour minimum"
# "Systolic blood pressure 24 hour minimum"
# "Systolic blood pressure 24 hour minimum"
# "Systolic blood pressure 8 hour maximum"
# "Systolic blood pressure 8 hour maximum"
# "Systolic blood pressure 8 hour maximum"
# "Systolic blood pressure 8 hour maximum"
# "Systolic blood pressure 8 hour minimum"
# "Systolic blood pressure 8 hour minimum"
# "Systolic blood pressure 8 hour minimum"
# "Systolic blood pressure 8 hour minimum"
# "Ascending thoracic aorta Systolic blood pressure"
# "Ascending thoracic aorta Systolic blood pressure"
# "Ascending thoracic aorta Systolic blood pressure"
# "Ascending thoracic aorta Systolic blood pressure"
# "Inferior mesenteric artery Systolic blood pressure"
# "Inferior mesenteric artery Systolic blood pressure"
# "Inferior mesenteric artery Systolic blood pressure"
# "Inferior mesenteric artery Systolic blood pressure"
# "Left pulmonary artery Systolic blood pressure"
# "Left pulmonary artery Systolic blood pressure"
# "Left pulmonary artery Systolic blood pressure"
# "Left pulmonary artery Systolic blood pressure"
# "Right pulmonary artery Systolic blood pressure"
# "Right pulmonary artery Systolic blood pressure"
# "Right pulmonary artery Systolic blood pressure"
# "Right pulmonary artery Systolic blood pressure"
# "Neonatal pressure ulcer risk evaluation [NSRAS]"
# "Neonatal pressure ulcer risk evaluation [NSRAS]"
# "Neonatal pressure ulcer risk evaluation [NSRAS]"
# "Neonatal pressure ulcer risk evaluation [NSRAS]"
# "Number of pressure injuries - unstageable due to coverage of wound bed by slough/eschar [CMS Assessment]"
# "Number of pressure injuries - unstageable due to coverage of wound bed by slough/eschar [CMS Assessment]"
# "Number of pressure injuries - unstageable due to coverage of wound bed by slough/eschar [CMS Assessment]"
# "Number of pressure injuries - unstageable due to coverage of wound bed by slough/eschar [CMS Assessment]"
# "Number of pressure injuries - unstageable due to non-removable dressing or device [CMS Assessment]"
# "Number of pressure injuries - unstageable due to non-removable dressing or device [CMS Assessment]"
# "Number of pressure injuries - unstageable due to non-removable dressing or device [CMS Assessment]"
# "Number of pressure injuries - unstageable due to non-removable dressing or device [CMS Assessment]"
# "Number of pressure injuries - unstageable with suspected deep tissue injury in evolution [CMS Assessment]"
# "Number of pressure injuries - unstageable with suspected deep tissue injury in evolution [CMS Assessment]"
# "Number of pressure injuries - unstageable with suspected deep tissue injury in evolution [CMS Assessment]"
# "Number of pressure injuries - unstageable with suspected deep tissue injury in evolution [CMS Assessment]"
# "Number of unhealed pressure ulcers at each stage - at assessment and onset during this service"
# "Number of unhealed pressure ulcers at each stage - at assessment and onset during this service"
# "Number of unhealed pressure ulcers at each stage - at assessment and onset during this service"
# "Number of unhealed pressure ulcers at each stage - at assessment and onset during this service"
# "One or more unhealed pressure ulcer(s) at stage 2 or higher [CARE]"
# "One or more unhealed pressure ulcer(s) at stage 2 or higher [CARE]"
# "One or more unhealed pressure ulcer(s) at stage 2 or higher [CARE]"
# "One or more unhealed pressure ulcer(s) at stage 2 or higher [CARE]"
# "Airway pressure by Airway pressure monitor --on ventilator.volume targeted control"
# "Airway pressure by Airway pressure monitor --on ventilator.volume targeted control"
# "Airway pressure by Airway pressure monitor --on ventilator.volume targeted control"
# "Airway pressure by Airway pressure monitor --on ventilator.volume targeted control"
# "Air cylinder Pressure"
# "Air cylinder Pressure"
# "Air cylinder Pressure"
# "Air cylinder Pressure"
# "Air pipeline Pressure"
# "Air pipeline Pressure"
# "Air pipeline Pressure"
# "Air pipeline Pressure"
# "Gastric pressure"
# "Gastric pressure"
# "Gastric pressure"
# "Gastric pressure"
# "Nitrous oxide cylinder Pressure"
# "Nitrous oxide cylinder Pressure"
# "Nitrous oxide cylinder Pressure"
# "Nitrous oxide cylinder Pressure"
# "Oxygen cylinder Pressure"
# "Oxygen cylinder Pressure"
# "Oxygen cylinder Pressure"
# "Oxygen cylinder Pressure"
# "Nitrous oxide pipeline Pressure"
# "Nitrous oxide pipeline Pressure"
# "Nitrous oxide pipeline Pressure"
# "Nitrous oxide pipeline Pressure"
# "Oxygen pipeline Pressure"
# "Oxygen pipeline Pressure"
# "Oxygen pipeline Pressure"
# "Oxygen pipeline Pressure"
# Bilirubin
# Bilirubin
# Bilirubin
# Bilirubin
# Calcium^^corrected for albumin
# Calcium^^corrected for albumin
# Calcium^^corrected for albumin
# Calcium^^corrected for albumin
# Bilirubin
# Bilirubin
# Bilirubin
# Bilirubin
# Antibiotic XXX
# Antibiotic XXX
# Antibiotic XXX
# Antibiotic XXX
# Vancomycin
# Vancomycin
# Vancomycin
# Vancomycin
# Glucose
# Glucose
# Glucose
# Glucose
# Aspartate aminotransferase
# Aspartate aminotransferase
# Aspartate aminotransferase
# Aspartate aminotransferase
# Cefazolin
# Cefazolin
# Cefazolin
# Cefazolin
# Hepatitis B virus DNA
# Hepatitis B virus DNA
# Hepatitis B virus DNA
# Hepatitis B virus DNA
# Albumin
# Albumin
# Albumin
# Albumin
# Staphylococcus aureus.methicillin resistant isolate
# Staphylococcus aureus.methicillin resistant isolate
# Staphylococcus aureus.methicillin resistant isolate
# Staphylococcus aureus.methicillin resistant isolate
# Glucose
# Glucose
# Glucose
# Glucose
# Glucose^post CFst
# Glucose^post CFst
# Glucose^post CFst
# Glucose^post CFst
# Cholesterol.in HDL
# Cholesterol.in HDL
# Cholesterol.in HDL
# Cholesterol.in HDL
# Leukocytes
# Leukocytes
# Leukocytes
# Leukocytes
# Blood product disposition
# Blood product disposition
# Blood product disposition
# Blood product disposition
# Calcium.ionized
# Calcium.ionized
# Calcium.ionized
# Calcium.ionized
# Amylase
# Amylase
# Amylase
# Amylase
# Bicarbonate
# Bicarbonate
# Bicarbonate
# Bicarbonate
# Bilirubin
# Bilirubin
# Bilirubin
# Bilirubin
# Gentamicin
# Gentamicin
# Gentamicin
# Gentamicin
# ABO group
# ABO group
# ABO group
# ABO group
# Blood product unit ID
# Blood product unit ID
# Blood product unit ID
# Blood product unit ID
# Protein C
# Protein C
# Protein C
# Protein C
# Chloride
# Chloride
# Chloride
# Chloride
# Choriogonadotropin.beta subunit
# Choriogonadotropin.beta subunit
# Choriogonadotropin.beta subunit
# Choriogonadotropin.beta subunit
# Calcium
# Calcium
# Calcium
# Calcium
# Chloride
# Chloride
# Chloride
# Chloride
# Blood product type
# Blood product type
# Blood product type
# Blood product type
# Cobalamins
# Cobalamins
# Cobalamins
# Cobalamins
# Choriogonadotropin
# Choriogonadotropin
# Choriogonadotropin
# Choriogonadotropin
# Lymphocytes/100 leukocytes
# Lymphocytes/100 leukocytes
# Lymphocytes/100 leukocytes
# Lymphocytes/100 leukocytes
# Glucose
# Glucose
# Glucose
# Glucose
# Carbon dioxide
# Carbon dioxide
# Carbon dioxide
# Carbon dioxide
# Carbon dioxide
# Carbon dioxide
# Carbon dioxide
# Carbon dioxide
# Nitrofurantoin
# Nitrofurantoin
# Nitrofurantoin
# Nitrofurantoin
# Cholesterol
# Cholesterol
# Cholesterol
# Cholesterol
# Trimethoprim+Sulfamethoxazole
# Trimethoprim+Sulfamethoxazole
# Trimethoprim+Sulfamethoxazole
# Trimethoprim+Sulfamethoxazole
# Blood group antibody screen
# Blood group antibody screen
# Blood group antibody screen
# Blood group antibody screen
# Glucose^3H post 100 g glucose PO
# Glucose^3H post 100 g glucose PO
# Glucose^3H post 100 g glucose PO
# Glucose^3H post 100 g glucose PO
# Cortisol
# Cortisol
# Cortisol
# Cortisol
# Carcinoembryonic Ag
# Carcinoembryonic Ag
# Carcinoembryonic Ag
# Carcinoembryonic Ag
# Bilirubin.non-glucuronidated
# Bilirubin.non-glucuronidated
# Bilirubin.non-glucuronidated
# Bilirubin.non-glucuronidated
# Ciprofloxacin
# Ciprofloxacin
# Ciprofloxacin
# Ciprofloxacin
# Alkaline phosphatase
# Alkaline phosphatase
# Alkaline phosphatase
# Alkaline phosphatase
# C reactive protein
# C reactive protein
# C reactive protein
# C reactive protein
# Glucose
# Glucose
# Glucose
# Glucose
# Calcium.ionized
# Calcium.ionized
# Calcium.ionized
# Calcium.ionized
# Albumin/Globulin
# Albumin/Globulin
# Albumin/Globulin
# Albumin/Globulin
# Levofloxacin
# Levofloxacin
# Levofloxacin
# Levofloxacin
# Bilirubin.glucuronidated+Bilirubin.albumin bound
# ...
# "Malignant cells/100 leukocytes"
# "Malignant cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Mononuclear cells.immature/100 leukocytes"
# "Mononuclear cells.immature/100 leukocytes"
# "Mononuclear cells.immature/100 leukocytes"
# "Mononuclear cells.immature/100 leukocytes"
# "Mononuclear cells.atypical/100 leukocytes"
# "Mononuclear cells.atypical/100 leukocytes"
# "Mononuclear cells.atypical/100 leukocytes"
# "Mononuclear cells.atypical/100 leukocytes"
# "Unidentified cells/100 leukocytes"
# "Unidentified cells/100 leukocytes"
# "Unidentified cells/100 leukocytes"
# "Unidentified cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Plasma cells.centroblasts/100 leukocytes"
# "Plasma cells.centroblasts/100 leukocytes"
# "Plasma cells.centroblasts/100 leukocytes"
# "Plasma cells.centroblasts/100 leukocytes"
# "Plasma cells.centrocytes/100 leukocytes"
# "Plasma cells.centrocytes/100 leukocytes"
# "Plasma cells.centrocytes/100 leukocytes"
# "Plasma cells.centrocytes/100 leukocytes"
# "Mononuclear cells/leukocytes"
# "Mononuclear cells/leukocytes"
# "Mononuclear cells/leukocytes"
# "Mononuclear cells/leukocytes"
# "Mononuclear cells/leukocytes"
# "Mononuclear cells/leukocytes"
# "Mononuclear cells/leukocytes"
# "Mononuclear cells/leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Mononuclear cells/100 leukocytes"
# "Nonhematic cells/100 leukocytes"
# "Nonhematic cells/100 leukocytes"
# "Nonhematic cells/100 leukocytes"
# "Nonhematic cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Plasma cells/100 leukocytes"
# "Unidentified cells/100 leukocytes"
# "Unidentified cells/100 leukocytes"
# "Unidentified cells/100 leukocytes"
# "Unidentified cells/100 leukocytes"
# "Unspecified cells/leukocytes"
# "Unspecified cells/leukocytes"
# "Unspecified cells/leukocytes"
# "Unspecified cells/leukocytes"
# "Large unstained cells/100 leukocytes"
# "Large unstained cells/100 leukocytes"
# "Large unstained cells/100 leukocytes"
# "Large unstained cells/100 leukocytes"
# "Large unstained cells/100 leukocytes"
# "Large unstained cells/100 leukocytes"
# "Large unstained cells/100 leukocytes"
# "Large unstained cells/100 leukocytes"
# "Monocytoid cells/100 leukocytes"
# "Monocytoid cells/100 leukocytes"
# "Monocytoid cells/100 leukocytes"
# "Monocytoid cells/100 leukocytes"
# "Neoplastic cells/100 leukocytes"
# "Neoplastic cells/100 leukocytes"
# "Neoplastic cells/100 leukocytes"
# "Neoplastic cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Other cells/100 leukocytes"
# "Unspecified cells/100 leukocytes"
# "Unspecified cells/100 leukocytes"
# "Unspecified cells/100 leukocytes"
# "Unspecified cells/100 leukocytes"
# "Mononuclear cells.atypical/100 leukocytes"
# "Mononuclear cells.atypical/100 leukocytes"
# "Mononuclear cells.atypical/100 leukocytes"
# "Mononuclear cells.atypical/100 leukocytes"
# "Mononuclear cells/leukocytes"
# "Mononuclear cells/leukocytes"
# "Mononuclear cells/leukocytes"
# "Mononuclear cells/leukocytes"
# "Plasma cells/leukocytes"
# "Plasma cells/leukocytes"
# "Plasma cells/leukocytes"
# "Plasma cells/leukocytes"
# "Plasma cells/leukocytes"
# "Plasma cells/leukocytes"
# "Plasma cells/leukocytes"
# "Plasma cells/leukocytes"
# "Unidentified cells/leukocytes"
# "Unidentified cells/leukocytes"
# "Unidentified cells/leukocytes"
# "Unidentified cells/leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/100 leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Mesothelial cells/leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Polymorphonuclear cells/100 leukocytes"
# "Intravascular mean"
# "Intravascular mean"
# "Intravascular mean"
# "Intravascular mean"
# "Intravascular mean"
# "Intravascular mean"
# "Intravascular mean"
# "Intravascular mean"
# "Pressure max^during inspiration"
# "Pressure max^during inspiration"
# "Pressure max^during inspiration"
# "Pressure max^during inspiration"
# "Pressure mean^during inspiration"
# "Pressure mean^during inspiration"
# "Pressure mean^during inspiration"
# "Pressure mean^during inspiration"
# "Current number of unhealed pressure injuries at each stage - follow-up or discharge"
# "Current number of unhealed pressure injuries at each stage - follow-up or discharge"
# "Current number of unhealed pressure injuries at each stage - follow-up or discharge"
# "Current number of unhealed pressure injuries at each stage - follow-up or discharge"
# Diameter.any.max
# Diameter.any.max
# Diameter.any.max
# Diameter.any.max
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular end diastolic"
# "Intravascular end diastolic"
# "Intravascular end diastolic"
# "Intravascular end diastolic"
# "Intravascular mean"
# "Intravascular mean"
# "Intravascular mean"
# "Intravascular mean"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular diastolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Intravascular systolic"
# "Neonatal pressure ulcer risk evaluation"
# "Neonatal pressure ulcer risk evaluation"
# "Neonatal pressure ulcer risk evaluation"
# "Neonatal pressure ulcer risk evaluation"
# "Number of pressure injuries - unstageable due to coverage of wound bed by slough &or eschar"
# "Number of pressure injuries - unstageable due to coverage of wound bed by slough &or eschar"
# "Number of pressure injuries - unstageable due to coverage of wound bed by slough &or eschar"
# "Number of pressure injuries - unstageable due to coverage of wound bed by slough &or eschar"
# "Number of pressure injuries - unstageable due to non-removable dressing or device"
# "Number of pressure injuries - unstageable due to non-removable dressing or device"
# "Number of pressure injuries - unstageable due to non-removable dressing or device"
# "Number of pressure injuries - unstageable due to non-removable dressing or device"
# "Number of pressure injuries - unstageable with suspected deep tissue injury in evolution"
# "Number of pressure injuries - unstageable with suspected deep tissue injury in evolution"
# "Number of pressure injuries - unstageable with suspected deep tissue injury in evolution"
# "Number of pressure injuries - unstageable with suspected deep tissue injury in evolution"
# "Number of unhealed pressure ulcers at each stage - at assessment and onset during this service"
# "Number of unhealed pressure ulcers at each stage - at assessment and onset during this service"
# "Number of unhealed pressure ulcers at each stage - at assessment and onset during this service"
# "Number of unhealed pressure ulcers at each stage - at assessment and onset during this service"
# "One or more unhealed pressure ulcer(s) at stage 2 or higher"
# "One or more unhealed pressure ulcer(s) at stage 2 or higher"
# "One or more unhealed pressure ulcer(s) at stage 2 or higher"
# "One or more unhealed pressure ulcer(s) at stage 2 or higher"
# "Pressure.airway^on ventilator.volume targeted control"
# "Pressure.airway^on ventilator.volume targeted control"
# "Pressure.airway^on ventilator.volume targeted control"
# "Pressure.airway^on ventilator.volume targeted control"
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# Pressure
# (200,) (200,)

# %% [markdown]
# #### Calculating Similarity Scores
#
# The package spacy allows an already builded model to download in order to build similarity scores between text corpuses.

# %%
#With the use of NLP Package of spacy and the downloaded model we calculate values in the range of [0,1]. 
#As Higher the score as more similar the query and the compared text is. 
def compute_similarity_score(dataframe,column,name) -> pd.DataFrame:
    similarity_score=[]
    for idx,article in enumerate(dataframe[column]):
        similarity_score.append(nlp(query_to_str(dataframe["query"][idx])).similarity(nlp(article)))
    return pd.DataFrame(similarity_score, columns=[name])

df["lcmon_ss"] = compute_similarity_score(df, "long_common_name", "lcmon_ss")
df["cmp_ss"] = compute_similarity_score(df, "component", "cmp_ss")
# Out:
# <ipython-input-117-1287bc9757c0>:6: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity_score.append(nlp(query_to_str(dataframe["query"][idx])).similarity(nlp(article)))

# %% [markdown]
# #### Description for identifying ranking results

# %%
#In order to identify the results of our predictions we need an identifier. Since Loinc already uses its own identifiers,
#a special loinc number, we use the same number for identification. 
description = []
for idx in range(len(df)):
    description.append(f' #docid = {df.loinc_num[idx]} {df.long_common_name[idx]}')
print(len(description))
# Out:
# 124

# %%
#All columns that we use for the listwise ranking algorithm adaRank. 
prep_df = df[["label","qid","lcmon_ss","lcmon_tf","cmp_tf","cmp_ss"]] 
print(prep_df)
# Out:
#     label qid  lcmon_ss  lcmon_tf    cmp_tf    cmp_ss
# 0       1   3  0.828310  0.055556  0.038462  0.654976
# 1       1   3  0.827685  0.058824  0.038462  0.654976
# 2       1   3  0.912173  0.045455  0.024390  0.530968
# 3       1   3  0.912173  0.045455  0.024390  0.530968
# 4       1   3  0.811331  0.049180  0.030303  0.497262
# ..    ...  ..       ...       ...       ...       ...
# 119     0   3  0.547386  0.000000  0.000000  0.472740
# 120     0   3  0.405370  0.000000  0.000000  0.472740
# 121     0   3  0.512250  0.000000  0.000000  0.472740
# 122     0   3  0.439458  0.000000  0.000000  0.472740
# 123     0   3  0.547004  0.000000  0.000000  0.472740
#
# [124 rows x 6 columns]

# %% [markdown]
# ### Scaling Data
#
# Since we used an unorthodoxed approach by just adding the tf scores together, we need Scale the values. Otherwise the difference between the similartiy scores and the aggregated tf scores could lead to a biased result. Furthermore we scale all numerical values with MinMaxScaler. MinMaxScaler dosent treat outliers very well. But our assesment is, that outliers represent a very high similarity and therefore dont need to be avoided because they likely indicate a very good match between query and searched Loinc entry

# %%
from sklearn.preprocessing import MinMaxScaler

cols = list(prep_df[["lcmon_ss","lcmon_tf","cmp_tf","cmp_ss"]])
prep_df.values[:] = MinMaxScaler().fit_transform(prep_df)
prep_df = pd.DataFrame(prep_df)
print(prep_df.columns)
print(len(prep_df))

prep_df.shape
# Out:
# Index(['label', 'qid', 'lcmon_ss', 'lcmon_tf', 'cmp_tf', 'cmp_ss'], dtype='object')
# 124
# (124, 6)

# %% [markdown]
# ### Train / Test / Validation Split and converting data into sparse matrix
#
# Since we are using the implementation by the github user: https://github.com/rueycheng/AdaRank the format of an sparse matrix is required.
#
# #### Split the dataset

# %%
#Train Test Split. After taking the train test split we split the test set another time in order to get a test and 
#a validation set
X = prep_df[["qid","lcmon_ss","lcmon_tf","cmp_tf","cmp_ss"]]
y = prep_df[["label"]].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.25, random_state=42)

# %% [markdown]
# #### Dump to svmlight file

# %%
from sklearn.datasets import dump_svmlight_file

#This function adds the identifier als already described to the svmlight outputed textfile in order to identify the ranked
#documents
def add_comments(description, indexes, file_name):
    with open(file_name, 'r') as f:
        file_lines = [''.join([x.strip(), description[indexes[idx]], '\n']) for idx,x in enumerate(f.readlines())]
    with open(file_name, 'w') as f:
        f.writelines(file_lines) 

#Function to save the preprocessed dataframe into svmlight format
def dump_to_svmlf(df,y,name,descriptio): 
    X = df[["lcmon_ss","lcmon_tf","cmp_tf","cmp_ss"]]
    qid = df[["qid"]].values.ravel()
    y = y.values.ravel()
    f = f"./{name}.txt"
    #print(y.shape)
    #print(len(X),len(y),len(qid))
    dump_svmlight_file(X, y,f, zero_based=False, comment=None, query_id=qid, multilabel=False)
    add_comments(description, X.index.values,f)

    
def save_to_folder(folder_path):
    dump_to_svmlf(X_train,pd.DataFrame(y_train),f"data/{folder_path}/train",description)
    dump_to_svmlf(X_test,pd.DataFrame(y_test),f"data/{folder_path}/test",description)
    dump_to_svmlf(X_val,pd.DataFrame(y_val),f"data/{folder_path}/vali",description)


#Change regarding the  used query and used dataset
save_to_folder("extend_ds/q3")
